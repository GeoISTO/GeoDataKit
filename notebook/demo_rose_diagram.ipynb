# %%
import GeoDataKit.geoplot as gp
import GeoDataKit.dataset as dataset

# %%
dataset.list_dataset()
# Out:
# ['orientation']

# %%
desc = dataset.list_dataset(description=True)
print(desc["orientation"])
# Out:
# A series of orientation values given as azimuth from North. The orientation values are contained in the "strike_deg" column. They are given in degrees, clockwise from North, ranging from 0 to 360 °. The values are categorized by the "category" column. A total of 300 values are contained in the dataset, grouped in 3 categories:
#  - Cat1:  50 values, random around  50 °, ranging [35,65]
#  - Cat2: 150 values, random around 320 °, ranging [290,350]
#  - Rand: 100 values, random ranging [0,360]
# Values are rounded to unit integers.

# %%
direction_data = dataset.get_dataset("orientation")
direction_data.head()
# Out:
#    strike_deg category
# 0         106     Cat1
# 1         108     Cat1
# 2         111     Cat1
# 3          95     Cat1
# 4          92     Cat1

# %%
gp.rose_diagram(direction_data)

# %%
gp.rose_diagram(direction_data, category_label="category", bin_width=20,
                 color_palette= "bright",
                 category_order= ["Rand","Cat1","Cat2"],
                 stat_type= "density",
                 x_axis_label= "Orientation (°)",
                 y_axis_label_location= "north")

# %%
gp.rose_diagram(direction_data, category_label="category", bin_width=15,
                 color_palette= "pastel",
                 category_order= None,
                 stat_type= "count",
                 x_axis_label= "Orientation (°)",
                 y_axis_label_location= "left",
                 bin_shape= "bars",
                 category_interaction= "proportion"
               )
